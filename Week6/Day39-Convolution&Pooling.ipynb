# %% [markdown]
# **Convolution & Pooling (Core of CNN)**

# %% [raw]
# # Convolution Math
# (New pixel) = sum(Filter * Image patch)

# %% [raw]
# # Feature Map
# Original photo -> simplified pattern image

# %% [raw]
# # Pooling Layer(Why Needed)
#
# [1 5
#  2 3] -> 5

# %% [markdown]
# Tiny Code Example

# %%
from tensorflow.keras.layers import Conv2D,MaxPooling2D

Conv2D(32,(3,3), activation="relu")
MaxPooling2D(2,2)
# Out:
# <MaxPooling2D name=max_pooling2d, built=True>

# %% [raw]
# conv -> ReLU -> Pool -> Repeat
