# %%
from transformers import pipeline

qa = pipeline("question-answering")

context = "Hugging Face is an AI company that provides open-source tools."
question = "What does Hugging Face provide?"

results = qa(question=question,context=context)

print(f"Quastion: {question}")
print(f"Answer: {results['answer']}")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
# Quastion: What does Hugging Face provide?
# Answer: open-source tools

# %%
context = "Chatgpt is a open ai"
question = "Why chatgpt is free?"

results = qa(question=question,context=context)

print(f"question: {question}")
print(f"Answer: {results['answer']}")
# Out:
# question: Why chatgpt is free?
# Answer: open ai
